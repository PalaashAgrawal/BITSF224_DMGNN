# %% [markdown]
# Github repo: https://github.com/limaosen0/DMGNN

# %% [markdown]
# # Setup

# %%
from google.colab import drive 
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd
# Out:
# /root

# %%
% cd /content/drive/My\ Drive/AI\ Stuff/projects/DMGNN\ ML\ Course
# !git clone https://github.com/limaosen0/DMGNN
# Out:
# /content/drive/My Drive/AI Stuff/projects/DMGNN ML Course
# Cloning into 'DMGNN'...
# remote: Enumerating objects: 903, done.
# remote: Total 903 (delta 0), reused 0 (delta 0), pack-reused 903
# Receiving objects: 100% (903/903), 162.47 MiB | 13.49 MiB/s, done.
# Resolving deltas: 100% (260/260), done.
# Checking out files: 100% (321/321), done.

# %%
# %cd DMGNN
# !cd torchlight && python setup.py install
# Out:
# /content/drive/My Drive/AI Stuff/projects/DMGNN ML Course/DMGNN
# running install
# running bdist_egg
# running egg_info
# writing torchlight.egg-info/PKG-INFO
# writing dependency_links to torchlight.egg-info/dependency_links.txt
# writing top-level names to torchlight.egg-info/top_level.txt
# writing manifest file 'torchlight.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/torchlight
# copying build/lib/torchlight/__init__.py -> build/bdist.linux-x86_64/egg/torchlight
# copying build/lib/torchlight/gpu.py -> build/bdist.linux-x86_64/egg/torchlight
# copying build/lib/torchlight/io.py -> build/bdist.linux-x86_64/egg/torchlight
# byte-compiling build/bdist.linux-x86_64/egg/torchlight/__init__.py to __init__.cpython-36.pyc
# ...

# %%
# %ls
# Out:
# cmu-long/   config/  h36m-long/   img/     README.md
# cmu-short/  data/    h36m-short/  LICENSE  torchlight/

# %%
% cd cmu-short
# !python main.py prediction -c ../config/CMU/short/train.yaml
# Out:
# [Errno 2] No such file or directory: 'cmu-short'
# /content/drive/My Drive/AI Stuff/projects/DMGNN ML Course/DMGNN/cmu-short
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "main.py", line 22, in <module>
#     p = Processor(sys.argv[2:])
#   File "/content/drive/My Drive/AI Stuff/projects/DMGNN ML Course/DMGNN/cmu-short/processor/processor.py", line 25, in __init__
#     self.init_environment()
#   File "/content/drive/My Drive/AI Stuff/projects/DMGNN ML Course/DMGNN/cmu-short/processor/processor.py", line 33, in init_environment
#     super().init_environment()
#   File "/content/drive/My Drive/AI Stuff/projects/DMGNN ML Course/DMGNN/cmu-short/processor/io.py", line 54, in init_environment
#     torchlight.occupy_gpu(gpus)
#   File "/usr/local/lib/python3.6/dist-packages/torchlight-1.0-py3.6.egg/torchlight/gpu.py", line 35, in occupy_gpu
# ...

# %%
import torch
torch._C._cuda_init()

# %%
# !pip install torch --upgrade
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# ...

# %%
# !pip install torchlight --upgrade
# Out:
# Requirement already up-to-date: torchlight in /usr/local/lib/python3.6/dist-packages/torchlight-1.0-py3.6.egg (1.0)

# %%
torch.__version__
# Out:
# '1.6.0+cu101'

# %% [markdown]
# Also install:
#
# https://github.com/una-dinosauria/human-motion-prediction.git
#
# https://github.com/facebookresearch/QuaterNet
